# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("C:\Rayyan Folder\STE AI Bootcamp\SP6\IBM-Supervised Classification\heart.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.target.nunique()
# Out:
# 2

# %%
sns.heatmap(round(df.corr(), 2))
# Out:
# <Axes: >

# %%
# Overview correlation between features
plt.figure(figsize=(13,8), dpi=500)
sns.heatmap(round(df.corr(),2), annot=True)
plt.title("Correlation Between Features", pad=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 4
#       2 plt.figure(figsize=(13,8), dpi=500)
#       3 sns.heatmap(round(df.corr(),2), annot=True)
# ----> 4 plt.title("Correlation Between Features", pad=30, fontdict=FONT)
#       5 plt.show()
#
# NameError: name 'FONT' is not defined

# %%
sns.pairplot(df)
# Out:
# Error in callback <function flush_figures at 0x000001D2FFE4C940> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Overview correlation between features
plt.figure(figsize=(13,8))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
ind = df.loc[df["chol"] >= 380].index

# %%
lst = [28, 85, 96, 220, 246]

df.loc[ind, "chol"] = 250

# %%
df.loc[df["chol"] >= 380].index
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Overview correlation between features
plt.figure(figsize=(13,8))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
scaler = StandardScaler()

df1 = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df1
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    0.952197  0.681005  1.973123  0.763956 -0.227488  2.394438 -1.005832
# 1   -1.915313  0.681005  1.002577 -0.092738  0.153211 -0.417635  0.898962
# 2   -1.474158 -1.468418  0.032031 -0.092738 -0.876915 -0.417635 -1.005832
# 3    0.180175  0.681005  0.032031 -0.663867 -0.160306 -0.417635  0.898962
# 4    0.290464 -1.468418 -0.938515 -0.663867  2.482190 -0.417635  0.898962
# ..        ...       ...       ...       ...       ...       ...       ...
# 298  0.290464 -1.468418 -0.938515  0.478391 -0.048336 -0.417635  0.898962
# 299 -1.033002  0.681005  1.973123 -1.234996  0.466727 -0.417635  0.898962
# 300  1.503641  0.681005 -0.938515  0.706843 -1.123249  2.394438  0.898962
# 301  0.290464  0.681005 -0.938515 -0.092738 -2.511679 -0.417635  0.898962
# 302  0.290464 -1.468418  0.032031 -0.092738 -0.160306 -0.417635 -1.005832
#
#       thalach     exang   oldpeak     slope        ca      thal    target
# ...

# %%
# Overview correlation between features
plt.figure(figsize=(13,8), dpi=500)
sns.heatmap(round(df1.corr(),2), annot=True)
plt.title("Correlation Between Features", pad=30)
plt.show()
